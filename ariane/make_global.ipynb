# %% [markdown]
# # rather than changing the fortran code.. maybe easier to make a netcdf file with the global attributes you need

# %%
import xarray as xr

# %%
grid = xr.open_dataset('/data1/parker/LO_data/grids/cas7/grid.nc')
grid6 = xr.open_dataset('/data1/parker/LO_data/grids/cas6/grid.nc')
globals = xr.open_dataset('/agdat1/parker/LO_roms/cas7_t0_x4b/f2018.01.02/ocean_his_0024.nc')

# %%
# compare grids
grid
# Out:
# <xarray.Dataset> Size: 110MB
# Dimensions:    (eta_rho: 1302, xi_rho: 663, eta_u: 1302, xi_u: 662,
#                 eta_v: 1301, xi_v: 663, eta_psi: 1301, xi_psi: 662)
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v,
#                                 eta_psi, xi_psi
# Data variables: (12/19)
#     h          (eta_rho, xi_rho) float64 7MB ...
#     pm         (eta_rho, xi_rho) float64 7MB ...
#     pn         (eta_rho, xi_rho) float64 7MB ...
#     f          (eta_rho, xi_rho) float64 7MB ...
#     xl         float64 8B ...
#     el         float64 8B ...
#     ...         ...
#     lon_v      (eta_v, xi_v) float64 7MB ...
#     lat_v      (eta_v, xi_v) float64 7MB ...
#     mask_v     (eta_v, xi_v) float64 7MB ...
#     lon_psi    (eta_psi, xi_psi) float64 7MB ...
#     lat_psi    (eta_psi, xi_psi) float64 7MB ...
#     mask_psi   (eta_psi, xi_psi) float64 7MB ...

# %%
grid6
# Out:
# <xarray.Dataset> Size: 131MB
# Dimensions:      (eta_rho: 1302, xi_rho: 663, eta_u: 1302, xi_u: 662,
#                   eta_v: 1301, xi_v: 663, eta_psi: 1301, xi_psi: 662,
#                   eta_psi_ex: 1303, xi_psi_ex: 664)
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v,
#                                 eta_psi, xi_psi, eta_psi_ex, xi_psi_ex
# Data variables: (12/22)
#     lat_rho      (eta_rho, xi_rho) float64 7MB ...
#     lon_rho      (eta_rho, xi_rho) float64 7MB ...
#     mask_rho     (eta_rho, xi_rho) float64 7MB ...
#     lat_u        (eta_u, xi_u) float64 7MB ...
#     lon_u        (eta_u, xi_u) float64 7MB ...
#     mask_u       (eta_u, xi_u) float64 7MB ...
#     ...           ...
#     f            (eta_rho, xi_rho) float64 7MB ...
#     pm           (eta_rho, xi_rho) float64 7MB ...
#     pn           (eta_rho, xi_rho) float64 7MB ...
#     xl           float64 8B ...
#     el           float64 8B ...
#     spherical    |S1 1B ...

# %%
grid.attrs['hc'] = globals.hc.values
grid.attrs['s_w'] = globals.s_w.values
grid.attrs['Cs_w'] = globals.Cs_w.values

# %%
grid.to_netcdf("/data1/bbeutel/LO_output/grid/grid_wattrs_cas7.nc")

# %%
atrs = xr.open_dataset("/data1/bbeutel/LO_output/grid/grid_wattrs_cas7.nc")
atrs
# Out:
# <xarray.Dataset> Size: 110MB
# Dimensions:    (eta_rho: 1302, xi_rho: 663, eta_u: 1302, xi_u: 662,
#                 eta_v: 1301, xi_v: 663, eta_psi: 1301, xi_psi: 662)
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v,
#                                 eta_psi, xi_psi
# Data variables: (12/19)
#     h          (eta_rho, xi_rho) float64 7MB ...
#     pm         (eta_rho, xi_rho) float64 7MB ...
#     pn         (eta_rho, xi_rho) float64 7MB ...
#     f          (eta_rho, xi_rho) float64 7MB ...
#     xl         float64 8B ...
#     el         float64 8B ...
#     ...         ...
#     lon_v      (eta_v, xi_v) float64 7MB ...
#     lat_v      (eta_v, xi_v) float64 7MB ...
#     mask_v     (eta_v, xi_v) float64 7MB ...
#     lon_psi    (eta_psi, xi_psi) float64 7MB ...
#     lat_psi    (eta_psi, xi_psi) float64 7MB ...
#     mask_psi   (eta_psi, xi_psi) float64 7MB ...
# Attributes:
#     hc:       10.0
# ...

# %%
grid7 = xr.open_dataset('/data1/parker/LO_data/grids/cas7/grid.nc')
grid7
# Out:
# <xarray.Dataset> Size: 110MB
# Dimensions:    (eta_rho: 1302, xi_rho: 663, eta_u: 1302, xi_u: 662,
#                 eta_v: 1301, xi_v: 663, eta_psi: 1301, xi_psi: 662)
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v,
#                                 eta_psi, xi_psi
# Data variables: (12/19)
#     h          (eta_rho, xi_rho) float64 7MB ...
#     pm         (eta_rho, xi_rho) float64 7MB ...
#     pn         (eta_rho, xi_rho) float64 7MB ...
#     f          (eta_rho, xi_rho) float64 7MB ...
#     xl         float64 8B ...
#     el         float64 8B ...
#     ...         ...
#     lon_v      (eta_v, xi_v) float64 7MB ...
#     lat_v      (eta_v, xi_v) float64 7MB ...
#     mask_v     (eta_v, xi_v) float64 7MB ...
#     lon_psi    (eta_psi, xi_psi) float64 7MB ...
#     lat_psi    (eta_psi, xi_psi) float64 7MB ...
#     mask_psi   (eta_psi, xi_psi) float64 7MB ...

# %%
grid6
# Out:
# <xarray.Dataset> Size: 131MB
# Dimensions:      (eta_rho: 1302, xi_rho: 663, eta_u: 1302, xi_u: 662,
#                   eta_v: 1301, xi_v: 663, eta_psi: 1301, xi_psi: 662,
#                   eta_psi_ex: 1303, xi_psi_ex: 664)
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v,
#                                 eta_psi, xi_psi, eta_psi_ex, xi_psi_ex
# Data variables: (12/22)
#     lat_rho      (eta_rho, xi_rho) float64 7MB ...
#     lon_rho      (eta_rho, xi_rho) float64 7MB ...
#     mask_rho     (eta_rho, xi_rho) float64 7MB ...
#     lat_u        (eta_u, xi_u) float64 7MB ...
#     lon_u        (eta_u, xi_u) float64 7MB ...
#     mask_u       (eta_u, xi_u) float64 7MB ...
#     ...           ...
#     f            (eta_rho, xi_rho) float64 7MB ...
#     pm           (eta_rho, xi_rho) float64 7MB ...
#     pn           (eta_rho, xi_rho) float64 7MB ...
#     xl           float64 8B ...
#     el           float64 8B ...
#     spherical    |S1 1B ...
